# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("C:/Users/nk098/Desktop/H2HBABBA1752.csv")

# %%
df.head()
# Out:
#   business_code cust_number    name_customer           clear_date  \
# 0          U001  0200799367   MCL associates  2019-09-03 00:00:00
# 1          U001  0200759878          SA corp  2019-02-06 00:00:00
# 2          U001  0200769623       WAL-MAR us  2019-11-12 00:00:00
# 3          U001  0200769623         WAL-MAR   2019-04-11 00:00:00
# 4          U001  0200799367  MCL corporation  2019-09-04 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2019.0  1.929749e+09   2019-08-16              20190815
# 1         2019.0  1.928645e+09   2019-01-21              20190118
# 2         2019.0  1.930071e+09   2019-10-30              20191029
# 3         2019.0  1.929024e+09   2019-03-25              20190325
# 4         2019.0  1.929519e+09   2019-06-21              20190620
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20190816   20190831.0              USD            RV
# 1                20190121   20190205.0              USD            RV
# 2                20191030   20191114.0              USD            RV
# 3                20190325   20190409.0              USD            RV
# 4                20190621   20190904.0              USD            RV
#
#    posting_id  area_business  total_open_amount  baseline_create_date  \
# 0         1.0            NaN           13712.63            20190816.0
# 1         1.0            NaN           32026.14            20190121.0
# 2         1.0            NaN           18398.17            20191030.0
# 3         1.0            NaN             643.47            20190325.0
# 4         1.0            NaN            4421.76            20190621.0
#
#   cust_payment_terms    invoice_id  isOpen
# 0               NAA8  1.929749e+09       0
# 1               NAH4  1.928645e+09       0
# 2               NAH4  1.930071e+09       0
# 3               NAH4  1.929024e+09       0
# 4               NAWN  1.929519e+09       0

# %%
df.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# area_business             50000
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    2
# isOpen                        0
# dtype: int64

# %%
df.shape
# Out:
# (50000, 19)

# %%
df.drop("area_business",axis = "columns",inplace=True)

# %%
df.head()
# Out:
#   business_code cust_number    name_customer           clear_date  \
# 0          U001  0200799367   MCL associates  2019-09-03 00:00:00
# 1          U001  0200759878          SA corp  2019-02-06 00:00:00
# 2          U001  0200769623       WAL-MAR us  2019-11-12 00:00:00
# 3          U001  0200769623         WAL-MAR   2019-04-11 00:00:00
# 4          U001  0200799367  MCL corporation  2019-09-04 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2019.0  1.929749e+09   2019-08-16              20190815
# 1         2019.0  1.928645e+09   2019-01-21              20190118
# 2         2019.0  1.930071e+09   2019-10-30              20191029
# 3         2019.0  1.929024e+09   2019-03-25              20190325
# 4         2019.0  1.929519e+09   2019-06-21              20190620
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20190816   20190831.0              USD            RV
# 1                20190121   20190205.0              USD            RV
# 2                20191030   20191114.0              USD            RV
# 3                20190325   20190409.0              USD            RV
# 4                20190621   20190904.0              USD            RV
#
#    posting_id  total_open_amount  baseline_create_date cust_payment_terms  \
# 0         1.0           13712.63            20190816.0               NAA8
# 1         1.0           32026.14            20190121.0               NAH4
# 2         1.0           18398.17            20191030.0               NAH4
# 3         1.0             643.47            20190325.0               NAH4
# 4         1.0            4421.76            20190621.0               NAWN
#
#      invoice_id  isOpen
# 0  1.929749e+09       0
# 1  1.928645e+09       0
# 2  1.930071e+09       0
# 3  1.929024e+09       0
# 4  1.929519e+09       0

# %%
df.drop("name_customer",axis = "columns",inplace=True)

# %%
df.drop("document_create_date",axis = "columns",inplace=True)

# %%
df.head()
# Out:
#   business_code cust_number           clear_date  buisness_year        doc_id  \
# 0          U001  0200799367  2019-09-03 00:00:00         2019.0  1.929749e+09
# 1          U001  0200759878  2019-02-06 00:00:00         2019.0  1.928645e+09
# 2          U001  0200769623  2019-11-12 00:00:00         2019.0  1.930071e+09
# 3          U001  0200769623  2019-04-11 00:00:00         2019.0  1.929024e+09
# 4          U001  0200799367  2019-09-04 00:00:00         2019.0  1.929519e+09
#
#   posting_date  document_create_date.1  due_in_date invoice_currency  \
# 0   2019-08-16                20190816   20190831.0              USD
# 1   2019-01-21                20190121   20190205.0              USD
# 2   2019-10-30                20191030   20191114.0              USD
# 3   2019-03-25                20190325   20190409.0              USD
# 4   2019-06-21                20190621   20190904.0              USD
#
#   document type  posting_id  total_open_amount  baseline_create_date  \
# 0            RV         1.0           13712.63            20190816.0
# 1            RV         1.0           32026.14            20190121.0
# 2            RV         1.0           18398.17            20191030.0
# 3            RV         1.0             643.47            20190325.0
# 4            RV         1.0            4421.76            20190621.0
#
#   cust_payment_terms    invoice_id  isOpen
# 0               NAA8  1.929749e+09       0
# 1               NAH4  1.928645e+09       0
# 2               NAH4  1.930071e+09       0
# 3               NAH4  1.929024e+09       0
# 4               NAWN  1.929519e+09       0

# %%
dups = df.pivot_table(index = ['cust_number'],aggfunc ='size')

# %%
dups
# Out:
# cust_number
# 0100000048      2
# 0100000051      4
# 0100000158      2
# 0100000161      2
# 0100000217      3
#              ...
# CC7470          1
# CCCA02        560
# CCU001         49
# CCU002        108
# CCU013        618
# Length: 1433, dtype: int64

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (48777, 16)

# %%
df.dtypes
# Out:
# business_code              object
# cust_number                object
# clear_date                 object
# buisness_year             float64
# doc_id                    float64
# posting_date               object
# document_create_date.1      int64
# due_in_date               float64
# invoice_currency           object
# document type              object
# posting_id                float64
# total_open_amount         float64
# baseline_create_date      float64
# cust_payment_terms         object
# invoice_id                float64
# isOpen                      int64
# dtype: object

# %%
df['clear_date'] = pd.to_datetime(df['clear_date'])

# %%
df.head()
# Out:
#   business_code cust_number clear_date  buisness_year        doc_id  \
# 0          U001  0200799367 2019-09-03         2019.0  1.929749e+09
# 1          U001  0200759878 2019-02-06         2019.0  1.928645e+09
# 2          U001  0200769623 2019-11-12         2019.0  1.930071e+09
# 3          U001  0200769623 2019-04-11         2019.0  1.929024e+09
# 4          U001  0200799367 2019-09-04         2019.0  1.929519e+09
#
#   posting_date  document_create_date.1  due_in_date invoice_currency  \
# 0   2019-08-16                20190816   20190831.0              USD
# 1   2019-01-21                20190121   20190205.0              USD
# 2   2019-10-30                20191030   20191114.0              USD
# 3   2019-03-25                20190325   20190409.0              USD
# 4   2019-06-21                20190621   20190904.0              USD
#
#   document type  posting_id  total_open_amount  baseline_create_date  \
# 0            RV         1.0           13712.63            20190816.0
# 1            RV         1.0           32026.14            20190121.0
# 2            RV         1.0           18398.17            20191030.0
# 3            RV         1.0             643.47            20190325.0
# 4            RV         1.0            4421.76            20190621.0
#
#   cust_payment_terms    invoice_id  isOpen
# 0               NAA8  1.929749e+09       0
# 1               NAH4  1.928645e+09       0
# 2               NAH4  1.930071e+09       0
# 3               NAH4  1.929024e+09       0
# 4               NAWN  1.929519e+09       0

# %%
df.dtypes
# Out:
# business_code                     object
# cust_number                       object
# clear_date                datetime64[ns]
# buisness_year                    float64
# doc_id                           float64
# posting_date                      object
# document_create_date.1             int64
# due_in_date                      float64
# invoice_currency                  object
# document type                     object
# posting_id                       float64
# total_open_amount                float64
# baseline_create_date             float64
# cust_payment_terms                object
# invoice_id                       float64
# isOpen                             int64
# dtype: object

# %%
new = [df['due_in_date']]

# %%
new
# Out:
# [0        20190831.0
#  1        20190205.0
#  2        20191114.0
#  3        20190409.0
#  4        20190904.0
#              ...
#  49995    20190120.0
#  49996    20200224.0
#  49997    20190822.0
#  49998    20191214.0
#  49999    20190625.0
#  Name: due_in_date, Length: 48777, dtype: float64]

# %%
df['due_in_date'] = pd.to_datetime(df['clear_date'], format='%Y%m%d')

# %%
df.head()
# Out:
#   business_code cust_number clear_date  buisness_year        doc_id  \
# 0          U001  0200799367 2019-09-03         2019.0  1.929749e+09
# 1          U001  0200759878 2019-02-06         2019.0  1.928645e+09
# 2          U001  0200769623 2019-11-12         2019.0  1.930071e+09
# 3          U001  0200769623 2019-04-11         2019.0  1.929024e+09
# 4          U001  0200799367 2019-09-04         2019.0  1.929519e+09
#
#   posting_date  document_create_date.1 due_in_date invoice_currency  \
# 0   2019-08-16                20190816  2019-09-03              USD
# 1   2019-01-21                20190121  2019-02-06              USD
# 2   2019-10-30                20191030  2019-11-12              USD
# 3   2019-03-25                20190325  2019-04-11              USD
# 4   2019-06-21                20190621  2019-09-04              USD
#
#   document type  posting_id  total_open_amount  baseline_create_date  \
# 0            RV         1.0           13712.63            20190816.0
# 1            RV         1.0           32026.14            20190121.0
# 2            RV         1.0           18398.17            20191030.0
# 3            RV         1.0             643.47            20190325.0
# 4            RV         1.0            4421.76            20190621.0
#
#   cust_payment_terms    invoice_id  isOpen
# 0               NAA8  1.929749e+09       0
# 1               NAH4  1.928645e+09       0
# 2               NAH4  1.930071e+09       0
# 3               NAH4  1.929024e+09       0
# 4               NAWN  1.929519e+09       0

# %%
df['delay'] = df.clear_date - df.due_in_date

# %%
df.isnull().sum()
# Out:
# business_code                0
# cust_number                  0
# clear_date                9673
# buisness_year                0
# doc_id                       0
# posting_date                 0
# document_create_date.1       0
# due_in_date               9673
# invoice_currency             0
# document type                0
# posting_id                   0
# total_open_amount            0
# baseline_create_date         0
# cust_payment_terms           0
# invoice_id                   2
# isOpen                       0
# delay                     9673
# dtype: int64

# %%
Listofcust=list(df['cust_payment_terms'].value_counts().index)

# %%
df['cust_payment_terms'].value_counts()
# Out:
# NAA8    19801
# NAH4    13159
# CA10     3645
# NAC6     1734
# NAM4     1303
#         ...
# NATX        1
# NAUN        1
# NAUI        1
# NACG        1
# NACE        1
# Name: cust_payment_terms, Length: 75, dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (39102, 17)

# %%
df.head()
# Out:
#   business_code cust_number clear_date  buisness_year        doc_id  \
# 0          U001  0200799367 2019-09-03         2019.0  1.929749e+09
# 1          U001  0200759878 2019-02-06         2019.0  1.928645e+09
# 2          U001  0200769623 2019-11-12         2019.0  1.930071e+09
# 3          U001  0200769623 2019-04-11         2019.0  1.929024e+09
# 4          U001  0200799367 2019-09-04         2019.0  1.929519e+09
#
#   posting_date  document_create_date.1 due_in_date invoice_currency  \
# 0   2019-08-16                20190816  2019-09-03              USD
# 1   2019-01-21                20190121  2019-02-06              USD
# 2   2019-10-30                20191030  2019-11-12              USD
# 3   2019-03-25                20190325  2019-04-11              USD
# 4   2019-06-21                20190621  2019-09-04              USD
#
#   document type  posting_id  total_open_amount  baseline_create_date  \
# 0            RV         1.0           13712.63            20190816.0
# 1            RV         1.0           32026.14            20190121.0
# 2            RV         1.0           18398.17            20191030.0
# 3            RV         1.0             643.47            20190325.0
# 4            RV         1.0            4421.76            20190621.0
#
#   cust_payment_terms    invoice_id  isOpen  delay
# 0               NAA8  1.929749e+09       0 0 days
# 1               NAH4  1.928645e+09       0 0 days
# 2               NAH4  1.930071e+09       0 0 days
# 3               NAH4  1.929024e+09       0 0 days
# 4               NAWN  1.929519e+09       0 0 days

# %%
df["cust_payment_terms"] = df["cust_payment_terms"].astype('category')#covnert into category datatype
# Out:
# C:\Users\nk098\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.dtypes
# Out:
# business_code                      object
# cust_number                        object
# clear_date                 datetime64[ns]
# buisness_year                     float64
# doc_id                            float64
# posting_date                       object
# document_create_date.1              int64
# due_in_date                datetime64[ns]
# invoice_currency                   object
# document type                      object
# posting_id                        float64
# total_open_amount                 float64
# baseline_create_date              float64
# cust_payment_terms               category
# invoice_id                        float64
# isOpen                              int64
# delay                     timedelta64[ns]
# dtype: object

# %%
df["cust_payment_terms"] = df["cust_payment_terms"].cat.codes#converted into categorical

# %%
df.head()
# Out:
#   business_code cust_number clear_date  buisness_year        doc_id  \
# 0          U001  0200799367 2019-09-03         2019.0  1.929749e+09
# 1          U001  0200759878 2019-02-06         2019.0  1.928645e+09
# 2          U001  0200769623 2019-11-12         2019.0  1.930071e+09
# 3          U001  0200769623 2019-04-11         2019.0  1.929024e+09
# 4          U001  0200799367 2019-09-04         2019.0  1.929519e+09
#
#   posting_date  document_create_date.1 due_in_date invoice_currency  \
# 0   2019-08-16                20190816  2019-09-03              USD
# 1   2019-01-21                20190121  2019-02-06              USD
# 2   2019-10-30                20191030  2019-11-12              USD
# 3   2019-03-25                20190325  2019-04-11              USD
# 4   2019-06-21                20190621  2019-09-04              USD
#
#   document type  posting_id  total_open_amount  baseline_create_date  \
# 0            RV         1.0           13712.63            20190816.0
# 1            RV         1.0           32026.14            20190121.0
# 2            RV         1.0           18398.17            20191030.0
# 3            RV         1.0             643.47            20190325.0
# 4            RV         1.0            4421.76            20190621.0
#
#    cust_payment_terms    invoice_id  isOpen  delay  body_style_cat
# 0                  20  1.929749e+09       0 0 days              20
# 1                  34  1.928645e+09       0 0 days              34
# 2                  34  1.930071e+09       0 0 days              34
# 3                  34  1.929024e+09       0 0 days              34
# 4                  67  1.929519e+09       0 0 days              67

# %%
df.drop("body_style_cat",axis = "columns",inplace=True)

# %%
df.describe()#since we dont have negative valuues in min so no need to filter
# Out:
#        buisness_year        doc_id  document_create_date.1  posting_id  \
# count   39102.000000  3.910200e+04            3.910200e+04     39102.0
# mean     2019.134827  2.011244e+09            2.019186e+07         1.0
# std         0.341543  2.767206e+08            3.270065e+03         0.0
# min      2019.000000  1.928490e+09            2.018123e+07         1.0
# 25%      2019.000000  1.929175e+09            2.019041e+07         1.0
# 50%      2019.000000  1.929738e+09            2.019072e+07         1.0
# 75%      2019.000000  1.930208e+09            2.019103e+07         1.0
# max      2020.000000  2.960617e+09            2.020023e+07         1.0
#
#        total_open_amount  baseline_create_date  cust_payment_terms  \
# count       39102.000000          3.910200e+04        39102.000000
# mean        32565.717548          2.019186e+07           26.344739
# std         40056.860656          3.270210e+03           12.350121
# min             2.700000          2.018121e+07            0.000000
# 25%          4837.370000          2.019041e+07           20.000000
# 50%         17500.985000          2.019072e+07           20.000000
# 75%         47125.737500          2.019103e+07           34.000000
# max        660202.550000          2.020031e+07           70.000000
#
#          invoice_id   isOpen            delay
# count  3.910200e+04  39102.0            39102
# mean   2.011244e+09      0.0  0 days 00:00:00
# std    2.767206e+08      0.0  0 days 00:00:00
# min    1.928490e+09      0.0  0 days 00:00:00
# 25%    1.929175e+09      0.0  0 days 00:00:00
# 50%    1.929738e+09      0.0  0 days 00:00:00
# 75%    1.930208e+09      0.0  0 days 00:00:00
# max    2.960617e+09      0.0  0 days 00:00:00

# %%
unique_val = df["posting_id"].unique()

# %%
unique_val#hence unique value is 1 not need to take coloumn as a feature
# Out:
# array([1.])

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
carrier_count = df['cust_payment_terms'].value_counts()
sns.set(style="darkgrid")
sns.barplot(carrier_count.index, carrier_count.values, alpha=0.9)
plt.title('Frequency Distribution of Carriers')
plt.ylabel('Number of Occurrences', fontsize=12)

plt.xlabel('Carrier', fontsize=12)
plt.show()

# %%
#lets find outliers

# %%
# IQR
Q1 = np.percentile(df['total_open_amount'], 25, 
                   interpolation = 'midpoint') 
  
Q3 = np.percentile(df['total_open_amount'], 75,
                   interpolation = 'midpoint') 
IQR = Q3 - Q1

# %%
IQR
# Out:
# 42287.08500000001

# %%
upper = df['total_open_amount'] >= (Q3+1.5*IQR)
  
print("Upper bound:",upper)
print(np.where(upper))
  
# Below Lower bound
lower = df['total_open_amount'] <= (Q1-1.5*IQR)
print("Lower bound:", lower)
print(np.where(lower))
# Out:
# Upper bound: 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
# Name: total_open_amount, Length: 39102, dtype: bool
# (array([   24,    60,    78, ..., 39039, 39050, 39093], dtype=int64),)
# Lower bound: 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
# Name: total_open_amount, Length: 39102, dtype: bool
# (array([], dtype=int64),)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
